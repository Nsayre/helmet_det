# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(columns=['Model Parameters', 'Precision', 'Recall', 'mAP50', 'mAP50-95', 'Inference time'])
df.loc[0] = ["YOLOv5n 25epoch", 0.915, 0.852, 0.917, 0.565, "37.6ms"]
df.loc[1] = ["YOLOv8n 25epoch", 0.911, 0.862, 0.919, 0.640, "42.1ms"]
df.loc[2] = ["YOLOv8n 50epoch", 0.929, 0.847, 0.918, 0.644, "44.8ms"]
df.loc[3] = ["YOLOv8s 50epoch", 0.933, 0.883, 0.937, 0.665, "138.2ms"]
df.loc[4] = ["YOLOv8m 25epoch", 0.926, 0.892, 0.94, 0.669, "344.1ms"]

# sns.catplot(data=df)
sns.barplot(data=df, x="Model Parameters", y="Precision")
# Out:
# <Axes: xlabel='Model Parameters', ylabel='Precision'>

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("v8_8n_50e_best.pt")
# results = model("data/images/train/000009.jpg", show_labels=False)
results = model("ppe-detector-bad-example2_niclas-moser.png", show_labels=False, conf=0.5)


    # img = frame.to_ndarray(format="bgr24")

    # # Perform inference on the frame
    # results = model(img)

# img = results[0].plot(format="bgr24")
img = results[0].plot(labels=False)

for result in results:
    for detection in result.boxes.data.tolist():
        x1, y1, x2, y2, conf, class_id = map(int, detection[:6])
        label = f"{model.names[class_id]} {conf:.2f}"

        if model.names[class_id] == "helmet":
            color = (0, 255, 0)  # Green for helmet
            # helmet_count += 1
        else:
            color = (0, 0, 255)  # Red for no helmet
            # no_helmet_count += 1

        # Draw the bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), color, 10)
        # Draw the label
        # cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
# result[0].show()
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis('off')  # Hide the axis
plt.show()
# Out:
# image 1/1 /home/nick/code/Nsayre/helmet_det/ppe-detector-bad-example2_niclas-moser.png: 640x448 (no detections), 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
