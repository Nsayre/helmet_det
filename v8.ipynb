# %%
# Install the ultralytics package from PyPI
#!pip install ultralytics
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# ...

# %%
from ultralytics import YOLO

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolov8n.pt")

# %%
# Train the model using the 'dataset.yaml' dataset for 1 epochs
results = model.train(data="/home/sayaka/code/Nsayre/helmet_det/dataset.yaml", epochs=1, batch=1)
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.6 torch-2.3.0+cu121 CPU (AMD Ryzen 7 5825U with Radeon Graphics)
# ...

# %%
model.val()
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.6 torch-2.3.0+cu121 CPU (AMD Ryzen 7 5825U with Radeon Graphics)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/sayaka/code/Nsayre/helmet_det/data/labels/val.cache... 683 images, 0 backgrounds, 0 corrupt: 100%|██████████| 683/683 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 683/683 [00:43<00:00, 15.78it/s]
#                    all        683      11053      0.738      0.668      0.731      0.438
#                    hat        683        705      0.675      0.739      0.737      0.542
#                 person        683      10348      0.802      0.597      0.725      0.335
# Speed: 0.5ms preprocess, 45.6ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /home/sayaka/.pyenv/runs/detect/train42
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# ...

# %%
# Train the model using the 'dataset.yaml' dataset for 2 epochs
results_epochs2 = model.train(data="/home/sayaka/code/Nsayre/helmet_det/dataset.yaml", epochs=2, batch=1)
#I stopped it
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.6 torch-2.3.0+cu121 CPU (AMD Ryzen 7 5825U with Radeon Graphics)
# ...

# %%
import supervision as sv
import numpy as np

# %%
# use v8 epoch 1 result
sayaka_model = YOLO('best_v8.pt')

# %%
# try movie
sayaka_model(source="helmet_nothelmet.mp4", show=True, conf=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3918) /home/sayaka/code/Nsayre/helmet_det/helmet_nothelmet.mp4: 384x640 (no detections), 84.1ms
# video 1/1 (frame 2/3918) /home/sayaka/code/Nsayre/helmet_det/helmet_nothelmet.mp4: 384x640 (no detections), 112.1ms
# video 1/1 (frame 3/3918) /home/sayaka/code/Nsayre/helmet_det/helmet_nothelmet.mp4: 384x640 (no detections), 72.0ms
# ...

# %%
import cv2

# %%
camera = cv2.VideoCapture(0) #it couldn't run in ubuntu
# Out:
# [ WARN:0@729.102] global cap_v4l.cpp:997 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@729.102] global obsensor_uvc_stream_channel.cpp:159 getStreamChannelGroup Camera index out of range
